# %%
import exp_utils

#Folder containing all experiment files
fileFolder = './'



source1 = fileFolder + 'qLearning_countF'
source2 = fileFolder + 'neuralNetQLearning_countF'
#source3 = fileFolder + 'lenoSelfPlay'
source3 = fileFolder + 'probModelQLearning_countF'
source4 = fileFolder + 'pureSelfPlay_countF'



name1 = 'Q-Learning'
name2 = 'SEPLEM-NN'
name3 = 'SEPLEM-Prob'
name4 = 'Self-Play'


#startingCumulative = 1500

#Prepare intermediary files with experiment's summary.
exp_utils.collect_experiment_data(source1, runs = 500)
exp_utils.summarize_experiment_data(source1)
#exp_utils.cumulative_experiment_data(source1,startingFrom=startingCumulative,hfo=False)
#exp_utils.collect_experiment_data(source2, runs = 500)
#exp_utils.summarize_experiment_data(source2)
#xp_utils.cumulative_experiment_data(source2,startingFrom=startingCumulative,hfo=True)
#exp_utils.collect_experiment_data(source3, runs =500)
#exp_utils.summarize_experiment_data(source3)
#exp_utils.collect_experiment_data(source4, runs =500)
#exp_utils.summarize_experiment_data(source4)


printCI = True


exp_utils.draw_graph(source1=source1, name1=name1, #source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,#source5=source5,name5=name5,source6=source6,name6=name6,
                     ci=printCI,bigFont=True,markEvery=10,
                     nCol=2)
exp_utils.draw_graph(source1=source1, name1=name1, #source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,#source5=source5,name5=name5,source6=source6,name6=name6,
                     ci=printCI,bigFont=True,markEvery=10,what='__SUMMARY_win',
                     nCol=2)
#exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,#source4=source4,name4=name4,#source5=source5,name5=name5,source6=source6,name6=name6,
#                     ci=printCI,bigFont=True,markEvery=10, what='__SUMMARY_win')
#exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,#source4=source4,name4=name4,#source5=source5,name5=name5,source6=source6,name6=name6,
#                     ci=printCI,bigFont=True,markEvery=10, what='__SUMMARY_draw')
#exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,#source4=source4,name4=name4,#source5=source5,name5=name5,source6=source6,name6=name6,
#                     ci=printCI,bigFont=True,markEvery=10, what='__SUMMARY_lose')
#exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,#source4=source4,name4=name4,#source5=source5,name5=name5,source6=source6,name6=name6,
#                     ci=printCI,what='__CUMULATIVE_rewards',xMin = startingCumulative,xMax=8000,bigFont = True,markEvery=50)

#exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,#source5=source5,name5=name5,source6=source6,name6=name6,
#                     ci=printCI,what='__SHIFTED_rewards',yMin=-15, yMax = 20,xMin = 0,xMax=4500,bigFont = True,markEvery=10)



source1 = fileFolder + 'qLearning_countF'
source2 = fileFolder + 'neuralNetQLearning_noF'
#source3 = fileFolder + 'lenoSelfPlay'
source3 = fileFolder + 'probModelQLearning_noF'
source4 = fileFolder + 'pureSelfPlay_noF'



name1 = 'Q-Learning'
name2 = 'SEPLEM-NN'
name3 = 'SEPLEM-Prob'
name4 = 'Self-Play'


#startingCumulative = 1500

#Prepare intermediary files with experiment's summary.
exp_utils.collect_experiment_data(source1, runs = 500)
exp_utils.summarize_experiment_data(source1)
#exp_utils.cumulative_experiment_data(source1,startingFrom=startingCumulative,hfo=False)
exp_utils.collect_experiment_data(source2, runs = 500)
exp_utils.summarize_experiment_data(source2)
#xp_utils.cumulative_experiment_data(source2,startingFrom=startingCumulative,hfo=True)
exp_utils.collect_experiment_data(source3, runs =500)
exp_utils.summarize_experiment_data(source3)
exp_utils.collect_experiment_data(source4, runs =500)
exp_utils.summarize_experiment_data(source4)



exp_utils.draw_graph(source1=source1, name1=name1,# source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,#source5=source5,name5=name5,source6=source6,name6=name6,
                     ci=printCI,bigFont=True,markEvery=10,
                     xMin = -100,xMax=8000,yMin=-16, yMax = -4,nCol=2)


source1 = fileFolder + 'probModelQLearning_noF'
source2 = fileFolder + 'probModelQLearning_noF_0.0'
#source3 = fileFolder + 'lenoSelfPlay'
source3 = fileFolder + 'probModelQLearning_noF_0.3'
source4 = fileFolder + 'probModelQLearning_noF_0.7'
source5 = fileFolder + 'probModelQLearning_noF_0.5'
source6 = fileFolder + 'probModelQLearning_noF_0.9'

name1 = 'Optimal'
name2 = 'Random'
name3 = 'p=0.3'
name4 = 'p=0.7'
name5 = '50'
name6 = '90'

#Prepare intermediary files with experiment's summary.
exp_utils.collect_experiment_data(source1, runs = 500)
exp_utils.summarize_experiment_data(source1)
#exp_utils.cumulative_experiment_data(source1,startingFrom=startingCumulative,hfo=False)
exp_utils.collect_experiment_data(source2, runs = 500)
exp_utils.summarize_experiment_data(source2)
#xp_utils.cumulative_experiment_data(source2,startingFrom=startingCumulative,hfo=True)
exp_utils.collect_experiment_data(source3, runs =500)
exp_utils.summarize_experiment_data(source3)
exp_utils.collect_experiment_data(source4, runs =500)
exp_utils.summarize_experiment_data(source4)
#exp_utils.collect_experiment_data(source5, runs =500)
#exp_utils.summarize_experiment_data(source5)
#exp_utils.collect_experiment_data(source6, runs =500)
#exp_utils.summarize_experiment_data(source6)

exp_utils.draw_graph(source1=source1, name1=name1, #source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,#source5=source5,name5=name5,source6=source6,name6=name6,
                     ci=printCI,bigFont=True,markEvery=10,nCol=2,xMin = -100, xMax=8000,yMin=-20)

    
source1 = fileFolder + 'probModelQLearning_noF'
compare1 = fileFolder + 'qLearning_countF'
source2 = fileFolder + 'probModelQLearning_noF_0.0'
compare2 = fileFolder + 'qLearning_noF_0.0'
source3 = fileFolder + 'probModelQLearning_noF_0.3'
compare3 = fileFolder + 'qLearning_noF_0.3'
source4 = fileFolder + 'probModelQLearning_noF_0.7'
compare4 = fileFolder + 'qLearning_noF_0.7'
source5 = fileFolder + 'probModelQLearning_noF_0.5'
compare5 = fileFolder + 'qLearning_noF_0.5'
source6 = fileFolder + 'probModelQLearning_noF_0.9'
compare6 = fileFolder + 'qLearning_noF_0.9'

name1 = 'Optimal'
name2 = 'Random'
name3 = 'p=0.3'
name4 = 'p=0.7'


#Prepare intermediary files with experiment's summary.
exp_utils.collect_experiment_data(source1, runs = 500)
exp_utils.collect_experiment_data(compare1, runs = 500)
exp_utils.diff_avg_data(source1,compare1,nameOutput='100')
exp_utils.collect_experiment_data(source2, runs = 500)
exp_utils.collect_experiment_data(compare2, runs = 500)
exp_utils.diff_avg_data(source2,compare2,nameOutput='0')
exp_utils.collect_experiment_data(source3, runs = 500)
exp_utils.collect_experiment_data(compare3, runs = 500)
exp_utils.diff_avg_data(source3,compare3,nameOutput='30')
exp_utils.collect_experiment_data(source4, runs = 500)
exp_utils.collect_experiment_data(compare4, runs = 500)
exp_utils.diff_avg_data(source4,compare4,nameOutput='50')
#exp_utils.collect_experiment_data(source5, runs = 500)
#exp_utils.collect_experiment_data(compare5, runs = 500)
#exp_utils.diff_avg_data(source5,compare5,nameOutput='70')
#exp_utils.collect_experiment_data(source6, runs = 500)
#exp_utils.collect_experiment_data(compare6, runs = 500)
#exp_utils.diff_avg_data(source6,compare6,nameOutput='90')



exp_utils.draw_diff_graph(source1 = source1, path1 = '__DIFF_100_reward',name1=name1,
                source2 = source2, path2 = '__DIFF_0_reward',name2=name2,
                source3 = source3, path3 = '__DIFF_30_reward',name3=name3,
                source4 = source4, path4 = '__DIFF_50_reward',name4=name4,
                #source5 = source5, path5 = '__DIFF_70_reward',name5=name5,
                #source6 = source6, path6 = '__DIFF_90_reward',name6=name6,
              ci=printCI,bigFont=True,markEvery=10,nCol=2)
               

source1 = fileFolder + 'qLearning_countF'
source2 = fileFolder + 'neuralNetQLearning_noF_0.7_transfer_fw'
source3 = fileFolder + 'probModelQLearning_noF_0.7_transfer_fw'



name1 = 'Q-Learning'
name2 = 'SEPLEM-NN'
name3 = 'SEPLEM-Prob'


#Prepare intermediary files with experiment's summary.
exp_utils.collect_experiment_data(source1, runs = 500)
exp_utils.summarize_experiment_data(source1)
#exp_utils.cumulative_experiment_data(source1,startingFrom=startingCumulative,hfo=False)
exp_utils.collect_experiment_data(source2, runs = 500)
exp_utils.summarize_experiment_data(source2)
exp_utils.collect_experiment_data(source3, runs = 500)
exp_utils.summarize_experiment_data(source3)


exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,#source4=source4,name4=name4,source5=source5,name5=name5,source6=source6,name6=name6,
                     ci=printCI,bigFont=True,markEvery=10)

source1 = fileFolder + 'qLearning_noF_0.7'
source2 = fileFolder + 'neuralNetQLearning_noF_0.7_transfer_fs'
source3 = fileFolder + 'probModelQLearning_noF_0.7_transfer_fs'







#Prepare intermediary files with experiment's summary.
exp_utils.collect_experiment_data(source1, runs = 500)
exp_utils.summarize_experiment_data(source1)
#exp_utils.cumulative_experiment_data(source1,startingFrom=startingCumulative,hfo=False)
exp_utils.collect_experiment_data(source2, runs = 500)
exp_utils.summarize_experiment_data(source2)
exp_utils.collect_experiment_data(source3, runs = 500)
exp_utils.summarize_experiment_data(source3)


exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,#source4=source4,name4=name4,source5=source5,name5=name5,source6=source6,name6=name6,
                     ci=printCI,bigFont=True,markEvery=10,nCol=2)
# Out:
# Could use 1 runs from expected 500
# Could use 1 runs from expected 500
# Could use 0 runs from expected 500
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-bd145ef2e3a2> in <module>()
#      78 exp_utils.summarize_experiment_data(source1)
#      79 #exp_utils.cumulative_experiment_data(source1,startingFrom=startingCumulative,hfo=False)
# ---> 80 exp_utils.collect_experiment_data(source2, runs = 500)
#      81 exp_utils.summarize_experiment_data(source2)
#      82 #xp_utils.cumulative_experiment_data(source2,startingFrom=startingCumulative,hfo=True)
#
# ~/gitProjects/checkers-AI/results/exp_utils.py in collect_experiment_data(source, algorithm, runs)
#      69         headerLine.append("Run"+str(run))
#      70
# ---> 71     with open(os.path.join(source, "__EVAL_reward"), 'w') as csvfile:
#      72             csvwriter = csv.writer(csvfile)
# ...
